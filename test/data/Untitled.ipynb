# %%
import pandas as pd

# %%
data = pd.read_csv('dataset.csv')

# %%
c = data['leading word'].value_counts()

# %%
c.to_frame()
# Out:
#                                                     leading word
# Yes                                                           35
# No                                                            34
# Date                                                          25
# Postcode                                                      22
# Given names                                                   22
# Signature                                                     17
# NO                                                            15
# YES                                                           15
# Family name                                                   14
# State                                                         14
# Email address                                                 12
# Date of birth                                                 10
# Address                                                        9
# ...

# %%
c.to_csv('count.csv')
