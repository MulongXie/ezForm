# %%
import pandas as pd

# %%
data = pd.read_csv('dataset.csv')

# %%
c = data['leading word'].value_counts()

# %%
c = c.to_frame()

# %%
c['leading word'].value_counts()
# Out:
# 1     376
# 2      41
# 3      34
# 4      18
# 5      12
# 8       4
# 7       2
# 22      2
# 15      2
# 14      2
# 6       2
# 35      1
# 34      1
# 10      1
# 12      1
# 17      1
# 25      1
# 9       1
# Name: leading word, dtype: int64

# %%
c
# Out:
#                                                     leading word
# Yes                                                           35
# No                                                            34
# Date                                                          25
# Postcode                                                      22
# Given names                                                   22
# Signature                                                     17
# YES                                                           15
# NO                                                            15
# State                                                         14
# Family name                                                   14
# Email address                                                 12
# Date of birth                                                 10
# Address                                                        9
# ...
